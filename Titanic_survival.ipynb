# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean = df['Age'].mean()
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.drop(columns="Cabin", inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
Survived=df['Survived'].value_counts().reset_index()
print(Survived)
# Out:
#    Survived  count
# 0         0    549
# 1         1    342

# %%
import seaborn as sns

sns.barplot(x='Survived', y='count', data=Survived)
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survived Counts')
plt.show()

# %%
survived_gender = df.groupby(['Sex', 'Survived']).size().unstack()

# %%
survived_gender.plot(kind='bar', stacked=True)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Survived Counts by Gender')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
#Make a column of Age group give easy and good insights
# Define age ranges
age_bins = [0, 30, 60, float('inf')]  # Define age ranges: 0-30 (Younger), 31-60 (Middle), 61 and above (Older)
age_labels = ['Younger', 'Middle', 'Older']

# %%
# Create age groups
df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
sns.countplot(data=df, x='Age_Group', order=['Younger', 'Middle', 'Older'])
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Count of Individuals in Each Age Group')
plt.show()

# %%
survived_counts = df.groupby(['Age_Group', 'Survived']).size().unstack()

survived_counts.plot(kind='bar', stacked=True)
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Survival Status by Age Group')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
# Out:
# <ipython-input-25-fe48fa3860b5>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survived_counts = df.groupby(['Age_Group', 'Survived']).size().unstack()

# %%
Pclass=df['Pclass'].value_counts().reset_index()
print(Pclass)
# Out:
#    Pclass  count
# 0       3    491
# 1       1    216
# 2       2    184

# %%
survived_counts = df.groupby(['Pclass', 'Survived']).size().unstack()

survived_counts.plot(kind='bar', stacked=True)
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.title('Survival Status by Pclass')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
SibSp=df['SibSp'].value_counts().reset_index()
print(SibSp)
# Out:
#    SibSp  count
# 0      0    608
# 1      1    209
# 2      2     28
# 3      4     18
# 4      3     16
# 5      8      7
# 6      5      5

# %%
survived_counts= df.groupby(['SibSp','Survived']).size().unstack()
survived_counts.plot(kind='bar', stacked=False)
plt.xlabel('SibSp')
plt.ylabel('Count')
plt.title('Survival Status by Sibp')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
survived_counts= df.groupby(['Parch','Survived']).size().unstack()
survived_counts.plot(kind='bar', stacked=False)
plt.xlabel('Parch')
plt.ylabel('Count')
plt.title('Survival Status by Parch')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
from inspect import FullArgSpec
#Make a column of Fare group give easy and good insights
# Define Fare ranges
Fare_bins = [0, 50, 100, float('inf')]  # Define Fare ranges: 0-50 (Low), 51-100 (Medium), 100 and above (high)
Fare_labels = ['Low', 'Medium', 'High']

# Create Fare groups
df['Fare_Group'] = pd.cut(df['Fare'], bins=Fare_bins, labels=Fare_labels, right=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
survived_counts= df.groupby(['Fare_Group','Survived']).size().unstack()
survived_counts.plot(kind='bar', stacked=False)
plt.xlabel('Fare')
plt.ylabel('Count')
plt.title('Survival Status by Fare')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
# Out:
# <ipython-input-33-a03d9066f052>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survived_counts= df.groupby(['Fare_Group','Survived']).size().unstack()

# %%
Embarked=df['Embarked'].value_counts().reset_index()
print(Embarked)
# Out:
#   Embarked  count
# 0        S    644
# 1        C    168
# 2        Q     77

# %%
survived_counts= df.groupby(['Embarked','Survived']).size().unstack()
survived_counts.plot(kind='bar', stacked=False)
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.title('Survival Status by Embarked')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
